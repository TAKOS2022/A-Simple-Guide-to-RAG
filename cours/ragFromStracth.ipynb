# %% [markdown]
# ## 1 - Introduction

# %% [markdown]
# ##### L'objectif est d'implementer un pipeline RAG complet (retrieval, generation, tests & observabilites) avec les tests dans le but de comprendre ce qui se passe a chaque etape.

# %% [markdown]
# ## 2 - Lecture documents PDF

# %%
# Installation des packages necessaires. Il faut mettre le point d'exclamation pour specifier que 
# ce dernier sera installer dans l'environnement google colab
# !pip install langchain_community langchain requests==2.32.4 pathlib

# %%
from pathlib import Path
from langchain_community.document_loaders import PyPDFLoader
from google.colab import drive
drive.mount('/content')


file_path = Path(
    "/content/rag/data/"
    "Restaurant_Le_Gourmet_Urbain_Documentation.pdf"
)

print(file_path.exists())  # DOIT retourner True
# Out:
# Failed to connect to the remote Jupyter Server 'https://8080-m-s-l4uqyzu5tzfr-a.us-west4-1.prod.colab.dev/'. Verify the server is running and reachable.
